# %% [markdown]
# # Restaurent Sales Data

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ## Read the Dataset

# %%
df = pd.read_csv("data/restaurent.csv")

# %%
df
# Out:
#      Unnamed: 0 Unnamed: 1  Unnamed: 2          Unnamed: 3 Unnamed: 4  \
# 0           NaN   Order ID        Date             Product      Price
# 1           NaN      10452   11/7/2022               Fries       3.49
# 2           NaN      10453   11/7/2022           Beverages       2.95
# 3           NaN      10454   11/7/2022       Sides & Other       4.99
# 4           NaN      10455   11/8/2022             Burgers      12.99
# ..          ...        ...         ...                 ...        ...
# 250         NaN      10709  12/28/2022       Sides & Other       4.99
# 251         NaN      10710  12/29/2022             Burgers      12.99
# 252         NaN      10711  12/29/2022  Chicken Sandwiches       9.95
# 253         NaN      10712  12/29/2022               Fries       3.49
# 254         NaN      10713  12/29/2022           Beverages       2.95
#
#     Unnamed: 5     Unnamed: 6      Unnamed: 7          Unnamed: 8 Unnamed: 9
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   Unnamed: 1  255 non-null    object
#  2   Unnamed: 2  255 non-null    object
#  3   Unnamed: 3  255 non-null    object
#  4   Unnamed: 4  255 non-null    object
#  5   Unnamed: 5  255 non-null    object
#  6   Unnamed: 6  255 non-null    object
#  7   Unnamed: 7  255 non-null    object
#  8   Unnamed: 8  255 non-null    object
#  9   Unnamed: 9  255 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 20.1+ KB

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Drop Unwanted Column

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
df.drop(columns='Unnamed: 0', inplace=True)

# %%
df.head()
# Out:
#   Unnamed: 1 Unnamed: 2     Unnamed: 3 Unnamed: 4 Unnamed: 5     Unnamed: 6  \
# 0   Order ID       Date        Product      Price   Quantity  Purchase Type
# 1      10452  11/7/2022          Fries       3.49     573.07        Online
# 2      10453  11/7/2022      Beverages       2.95     745.76        Online
# 3      10454  11/7/2022  Sides & Other       4.99     200.40      In-store
# 4      10455  11/8/2022        Burgers      12.99     569.67      In-store
#
#        Unnamed: 7          Unnamed: 8 Unnamed: 9
# 0  Payment Method             Manager       City
# 1       Gift Card    Tom      Jackson     London
# 2       Gift Card         Pablo Perez     Madrid
# 3       Gift Card       Joao    Silva     Lisbon
# 4     Credit Card       Walter Muller     Berlin

# %% [markdown]
# ### Change the column name

# %%
df.loc[0]
# Out:
# Unnamed: 1          Order ID
# Unnamed: 2              Date
# Unnamed: 3           Product
# Unnamed: 4             Price
# Unnamed: 5          Quantity
# Unnamed: 6     Purchase Type
# Unnamed: 7    Payment Method
# Unnamed: 8           Manager
# Unnamed: 9              City
# Name: 0, dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
df.columns = df.loc[0]

# %%
df.head()
# Out:
# 0  Order ID       Date        Product  Price  Quantity  Purchase Type  \
# 0  Order ID       Date        Product  Price  Quantity  Purchase Type
# 1     10452  11/7/2022          Fries   3.49    573.07        Online
# 2     10453  11/7/2022      Beverages   2.95    745.76        Online
# 3     10454  11/7/2022  Sides & Other   4.99    200.40      In-store
# 4     10455  11/8/2022        Burgers  12.99    569.67      In-store
#
# 0  Payment Method             Manager    City
# 0  Payment Method             Manager    City
# 1       Gift Card    Tom      Jackson  London
# 2       Gift Card         Pablo Perez  Madrid
# 3       Gift Card       Joao    Silva  Lisbon
# 4     Credit Card       Walter Muller  Berlin

# %% [markdown]
# ### Drop the unwanted 1st row

# %%
df.drop(0, inplace=True)

# %%
df.head()
# Out:
# 0 Order ID       Date             Product  Price Quantity Purchase Type  \
# 1    10452  11/7/2022               Fries   3.49   573.07       Online
# 2    10453  11/7/2022           Beverages   2.95   745.76       Online
# 3    10454  11/7/2022       Sides & Other   4.99   200.40     In-store
# 4    10455  11/8/2022             Burgers  12.99   569.67     In-store
# 5    10456  11/8/2022  Chicken Sandwiches   9.95   201.01     In-store
#
# 0 Payment Method             Manager    City
# 1      Gift Card    Tom      Jackson  London
# 2      Gift Card         Pablo Perez  Madrid
# 3      Gift Card       Joao    Silva  Lisbon
# 4    Credit Card       Walter Muller  Berlin
# 5    Credit Card       Walter Muller  Berlin

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    object
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    object
#  4   Quantity        254 non-null    object
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: object(9)
# memory usage: 18.0+ KB

# %% [markdown]
# ### Consider the Manager column

# %%
df.head()
# Out:
# 0 Order ID       Date             Product  Price Quantity Purchase Type  \
# 1    10452  11/7/2022               Fries   3.49   573.07       Online
# 2    10453  11/7/2022           Beverages   2.95   745.76       Online
# 3    10454  11/7/2022       Sides & Other   4.99   200.40     In-store
# 4    10455  11/8/2022             Burgers  12.99   569.67     In-store
# 5    10456  11/8/2022  Chicken Sandwiches   9.95   201.01     In-store
#
# 0 Payment Method             Manager    City
# 1      Gift Card    Tom      Jackson  London
# 2      Gift Card         Pablo Perez  Madrid
# 3      Gift Card       Joao    Silva  Lisbon
# 4    Credit Card       Walter Muller  Berlin
# 5    Credit Card       Walter Muller  Berlin

# %%
df.Manager
# Out:
# 1        Tom      Jackson
# 2             Pablo Perez
# 3           Joao    Silva
# 4           Walter Muller
# 5           Walter Muller
#               ...
# 250         Walter Muller
# 251         Walter Muller
# 252         Walter Muller
# 253         Walter Muller
# 254         Walter Muller
# Name: Manager, Length: 254, dtype: object

# %%
df.Manager.unique()
# Out:
# array(['Tom      Jackson', '       Pablo Perez', 'Joao    Silva',
#        'Walter Muller', 'Remy    Monet', 'Remy Monet',
#        '       Remy Monet', 'Remy     Monet', 'Pablo Perez',
#        'Pablo   Perez', 'Pablo  Perez', 'Pablo    Perez', 'Joao Silva',
#        'Tom Jackson'], dtype=object)

# %%
df.Manager.nunique()
# Out:
# 14

# %%
df['Manager'] = df['Manager'].str.strip().str.replace(r'\s+', ' ', regex=True)

# %%
df['Manager'].unique()
# Out:
# array(['Tom Jackson', 'Pablo Perez', 'Joao Silva', 'Walter Muller',
#        'Remy Monet'], dtype=object)

# %%
df['Manager'].nunique()
# Out:
# 5

# %% [markdown]
# ### Remove the duplicates records

# %%
df.head()
# Out:
# 0 Order ID       Date             Product  Price Quantity Purchase Type  \
# 1    10452  11/7/2022               Fries   3.49   573.07       Online
# 2    10453  11/7/2022           Beverages   2.95   745.76       Online
# 3    10454  11/7/2022       Sides & Other   4.99   200.40     In-store
# 4    10455  11/8/2022             Burgers  12.99   569.67     In-store
# 5    10456  11/8/2022  Chicken Sandwiches   9.95   201.01     In-store
#
# 0 Payment Method        Manager    City
# 1      Gift Card    Tom Jackson  London
# 2      Gift Card    Pablo Perez  Madrid
# 3      Gift Card     Joao Silva  Lisbon
# 4    Credit Card  Walter Muller  Berlin
# 5    Credit Card  Walter Muller  Berlin

# %%
df.describe()
# Out:
# 0      Order ID       Date  Product  Price Quantity Purchase Type  \
# count       254        254      254    254      254           254
# unique      254         53        5      7       29             3
# top       10452  12/3/2022  Burgers  12.99   200.40       Online
# freq          1          5       52     52       49           107
#
# 0      Payment Method      Manager    City
# count             254          254     254
# unique              3            5       5
# top       Credit Card  Tom Jackson  London
# freq              120           75      75

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %%
df.describe()
# Out:
# 0      Order ID       Date  Product  Price Quantity Purchase Type  \
# count       254        254      254    254      254           254
# unique      254         53        5      7       29             3
# top       10452  12/3/2022  Burgers  12.99   200.40       Online
# freq          1          5       52     52       49           107
#
# 0      Payment Method      Manager    City
# count             254          254     254
# unique              3            5       5
# top       Credit Card  Tom Jackson  London
# freq              120           75      75

# %%
df[df['Order ID'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %%
df[df['Order ID'] == 10483]
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %% [markdown]
# ### Comverting Datetype of columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    object
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    object
#  4   Quantity        254 non-null    object
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: object(9)
# memory usage: 18.0+ KB

# %%
df.Quantity = df.Quantity.astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    object
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    object
#  4   Quantity        254 non-null    float64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 18.0+ KB

# %%
df.Quantity = df.Quantity.round()

# %%
df.Quantity
# Out:
# 1      573.0
# 2      746.0
# 3      200.0
# 4      570.0
# 5      201.0
#        ...
# 250    200.0
# 251    754.0
# 252    281.0
# 253    630.0
# 254    678.0
# Name: Quantity, Length: 254, dtype: float64

# %%
df.Quantity = df.Quantity.astype(int)

# %%
df.Quantity
# Out:
# 1      573
# 2      746
# 3      200
# 4      570
# 5      201
#       ...
# 250    200
# 251    754
# 252    281
# 253    630
# 254    678
# Name: Quantity, Length: 254, dtype: int64

# %%
df['Order ID'] = df['Order ID'].astype(int)
df['Price'] = df['Price'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    int64
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    float64
#  4   Quantity        254 non-null    int64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 18.0+ KB

# %%
df.Date = pd.to_datetime(df.Date)

# %%
df.Date.dtype
# Out:
# dtype('<M8[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    int64
#  1   Date            254 non-null    datetime64[ns]
#  2   Product         254 non-null    object
#  3   Price           254 non-null    float64
#  4   Quantity        254 non-null    int64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(5)
# memory usage: 18.0+ KB

# %%
df
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1       10452 2022-11-07               Fries   3.49       573       Online
# 2       10453 2022-11-07           Beverages   2.95       746       Online
# 3       10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4       10455 2022-11-08             Burgers  12.99       570     In-store
# 5       10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 250     10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 251     10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 252     10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 253     10712 2022-12-29               Fries   3.49       630   Drive-thru
# 254     10713 2022-12-29           Beverages   2.95       678   Drive-thru
#
# 0   Payment Method        Manager    City
# ...

# %% [markdown]
# ## Analyzing Data

# %% [markdown]
# ### What was the Most Preferred Payment Method?

# %%
df.head()
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City
# 1      Gift Card    Tom Jackson  London
# 2      Gift Card    Pablo Perez  Madrid
# 3      Gift Card     Joao Silva  Lisbon
# 4    Credit Card  Walter Muller  Berlin
# 5    Credit Card  Walter Muller  Berlin

# %%
df['Payment Method'].unique()
# Out:
# array([' Gift Card', ' Credit Card', ' Cash'], dtype=object)

# %%
df['Payment Method'].nunique()
# Out:
# 3

# %%
df['Payment Method'].value_counts()
# Out:
# Payment Method
# Credit Card    120
# Cash            76
# Gift Card       58
# Name: count, dtype: int64

# %%
df['Payment Method'].value_counts(normalize=True)*100
# Out:
# Payment Method
# Credit Card    47.244094
# Cash           29.921260
# Gift Card      22.834646
# Name: proportion, dtype: float64

# %%
df['Payment Method'].value_counts().plot(kind='bar');

# %% [markdown]
# ### Which one was the Most Selling Product.

# %% [markdown]
# #### By Quantity

# %%
df.head()
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City
# 1      Gift Card    Tom Jackson  London
# 2      Gift Card    Pablo Perez  Madrid
# 3      Gift Card     Joao Silva  Lisbon
# 4    Credit Card  Walter Muller  Berlin
# 5    Credit Card  Walter Muller  Berlin

# %%
df.groupby('Product')['Quantity'].sum()
# Out:
# Product
# Beverages             34988
# Burgers               29018
# Chicken Sandwiches    11133
# Fries                 32023
# Sides & Other          9800
# Name: Quantity, dtype: int64

# %%
df.groupby('Product')['Quantity'].sum().sort_values(ascending=False)
# Out:
# Product
# Beverages             34988
# Fries                 32023
# Burgers               29018
# Chicken Sandwiches    11133
# Sides & Other          9800
# Name: Quantity, dtype: int64

# %%
most_quantity = df.groupby('Product')['Quantity'].sum().sort_values(ascending=False)
most_quantity
# Out:
# Product
# Beverages             34988
# Fries                 32023
# Burgers               29018
# Chicken Sandwiches    11133
# Sides & Other          9800
# Name: Quantity, dtype: int64

# %%
type(most_quantity)
# Out:
# pandas.core.series.Series

# %%
most_quantity = most_quantity.reset_index()

# %%
type(most_quantity)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.figure(figsize=(9,4))
plt.bar(most_quantity['Product'], most_quantity['Quantity'], color = ['red', 'black', 'green', 'yellow', 'cyan'], width=0.4)
plt.title('Most Selling Product - By Quantity')
plt.xlabel('Product')
plt.ylabel('Qauntity');

# %% [markdown]
# #### By Revenue

# %%
df['Revenue'] = df.Price * df.Quantity

# %%
df.groupby('Product')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Product
# Burgers               376943.82
# Fries                 125626.57
# Chicken Sandwiches    114612.45
# Beverages             103214.60
# Sides & Other          48902.00
# Name: Revenue, dtype: float64

# %%
most_revenue = df.groupby('Product')['Revenue'].sum().sort_values(ascending=False)

# %%
most_revenue =  most_revenue.reset_index()
most_revenue
# Out:
#    index             Product    Revenue
# 0      0             Burgers  376943.82
# 1      1               Fries  125626.57
# 2      2  Chicken Sandwiches  114612.45
# 3      3           Beverages  103214.60
# 4      4       Sides & Other   48902.00

# %%
type(most_revenue)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.figure(figsize=(9,4))
plt.bar(most_revenue['Product'], most_revenue['Revenue'], color = ['red', 'black', 'green', 'yellow', 'cyan'], width=0.3)
plt.title("Most Selling Product - By Revenue")
plt.xlabel("Product")
plt.ylabel("Revenue");

# %% [markdown]
# ### Which City had maximum revenue?

# %%
df.head()
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City  Revenue
# 1      Gift Card    Tom Jackson  London  1999.77
# 2      Gift Card    Pablo Perez  Madrid  2200.70
# 3      Gift Card     Joao Silva  Lisbon   998.00
# 4    Credit Card  Walter Muller  Berlin  7404.30
# 5    Credit Card  Walter Muller  Berlin  1999.95

# %%
df.City.unique()
# Out:
# array(['London', 'Madrid', 'Lisbon', 'Berlin', 'Paris'], dtype=object)

# %%
df.groupby('City')['Revenue'].sum().sort_values(ascending=False)
# Out:
# City
# Lisbon    241635.49
# London    211160.04
# Madrid    136154.24
# Berlin    100572.34
# Paris      79777.33
# Name: Revenue, dtype: float64

# %% [markdown]
# ### Which Manager earned maximum revenue?

# %%
df.Manager.unique()
# Out:
# array(['Tom Jackson', 'Pablo Perez', 'Joao Silva', 'Walter Muller',
#        'Remy Monet'], dtype=object)

# %%
df.groupby('Manager')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Manager
# Joao Silva       241635.49
# Tom Jackson      211160.04
# Pablo Perez      136154.24
# Walter Muller    100572.34
# Remy Monet        79777.33
# Name: Revenue, dtype: float64

# %% [markdown]
# ### Show the Date wise revenue.

# %%
df.head()
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City  Revenue
# 1      Gift Card    Tom Jackson  London  1999.77
# 2      Gift Card    Pablo Perez  Madrid  2200.70
# 3      Gift Card     Joao Silva  Lisbon   998.00
# 4    Credit Card  Walter Muller  Berlin  7404.30
# 5    Credit Card  Walter Muller  Berlin  1999.95

# %%
df.groupby('Date')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Date
# 2022-11-13    27661.97
# 2022-11-14    17829.62
# 2022-12-28    17606.46
# 2022-12-26    16994.82
# 2022-12-27    16994.82
# 2022-12-29    16789.21
# 2022-12-22    16589.58
# 2022-12-25    16587.98
# 2022-12-21    16390.58
# 2022-12-24    16388.98
# 2022-12-20    16000.88
# 2022-12-23    15999.28
# 2022-12-19    15793.04
# 2022-12-18    15592.77
# 2022-12-17    15397.92
# 2022-12-16    15000.65
# 2022-12-11    14996.50
# 2022-12-10    14601.05
# 2022-12-12    14601.05
# 2022-12-13    14601.05
# 2022-12-09    14601.05
# 2022-12-14    14592.21
# 2022-11-18    14400.78
# 2022-12-15    14397.36
# 2022-11-11    14393.21
# 2022-12-08    14198.36
# 2022-11-09    14194.28
# 2022-12-05    14194.28
# 2022-11-21    14003.84
# 2022-12-06    13999.43
# 2022-11-19    13998.09
# 2022-12-03    13990.52
# 2022-12-07    13990.52
# 2022-11-12    13990.52
# 2022-12-02    13990.52
# 2022-11-17    13990.52
# 2022-11-23    13796.00
# 2022-11-22    13601.15
# 2022-11-30    13600.82
# ...

# %%
df.plot('Date', 'Revenue', color='red', lw=2, figsize=(9,4))
plt.title('Date wise Revenue')
plt.xlabel('Date')
plt.ylabel('Revenue')
plt.show()

# %% [markdown]
# ### What was the Average Revenue?

# %%
df.head()
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City  Revenue
# 1      Gift Card    Tom Jackson  London  1999.77
# 2      Gift Card    Pablo Perez  Madrid  2200.70
# 3      Gift Card     Joao Silva  Lisbon   998.00
# 4    Credit Card  Walter Muller  Berlin  7404.30
# 5    Credit Card  Walter Muller  Berlin  1999.95

# %%
df.Revenue.mean()
# Out:
# np.float64(3028.737952755905)

# %% [markdown]
# ### What was the Average Revenue of November & December month?

# %%
df.head()
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City  Revenue
# 1      Gift Card    Tom Jackson  London  1999.77
# 2      Gift Card    Pablo Perez  Madrid  2200.70
# 3      Gift Card     Joao Silva  Lisbon   998.00
# 4    Credit Card  Walter Muller  Berlin  7404.30
# 5    Credit Card  Walter Muller  Berlin  1999.95

# %%
df['Month'] = df.Date.dt.month

# %%
df.head()
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City  Revenue  Month
# 1      Gift Card    Tom Jackson  London  1999.77     11
# 2      Gift Card    Pablo Perez  Madrid  2200.70     11
# 3      Gift Card     Joao Silva  Lisbon   998.00     11
# 4    Credit Card  Walter Muller  Berlin  7404.30     11
# 5    Credit Card  Walter Muller  Berlin  1999.95     11

# %%
month_11 = df[df['Month'] == 11]
month_11
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1       10452 2022-11-07               Fries   3.49       573       Online
# 2       10453 2022-11-07           Beverages   2.95       746       Online
# 3       10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4       10455 2022-11-08             Burgers  12.99       570     In-store
# 5       10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 109     10568 2022-11-30           Beverages   2.95       678       Online
# 110     10569 2022-11-30       Sides & Other   4.99       200       Online
# 128     10537 2022-11-24               Fries   3.49       630   Drive-thru
# 129     10538 2022-11-24           Beverages   2.95       746   Drive-thru
# 130     10539 2022-11-24       Sides & Other   4.99       200   Drive-thru
#
# 0   Payment Method        Manager    City  Revenue  Month
# ...

# %%
month_11.Revenue.mean()
# Out:
# np.float64(2938.1869026548666)

# %%
month_12 = df[df['Month'] == 12]
month_12
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 111     10570 2022-12-01             Burgers  12.99       493       Online
# 112     10571 2022-12-01  Chicken Sandwiches   9.95       201       Online
# 113     10572 2022-12-01               Fries   3.49       573       Online
# 114     10573 2022-12-01           Beverages   2.95       678       Online
# 115     10574 2022-12-01       Sides & Other   4.99       200       Online
# ..        ...        ...                 ...    ...       ...           ...
# 250     10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 251     10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 252     10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 253     10712 2022-12-29               Fries   3.49       630   Drive-thru
# 254     10713 2022-12-29           Beverages   2.95       678   Drive-thru
#
# 0   Payment Method        Manager    City  Revenue  Month
# ...

# %%
month_12.Revenue.mean()
# Out:
# np.float64(3101.3072340425533)

# %% [markdown]
# ### What was the  Standard Deviation of Revenue and Quantity?

# %%
df['Quantity'].std()
# Out:
# 214.97943096363838

# %%
df['Revenue'].std()
# Out:
# 2419.9325462715055

# %% [markdown]
# ### What was the Variance of Revenue and Quantity?

# %%
df['Quantity'].var()
# Out:
# 46216.155737449764

# %%
df.Revenue.var()
# Out:
# 5856073.528504092

# %% [markdown]
# ### Was the revenue increasing or decreasing over the time?

# %%
month_11 = df[df['Month'] == 11]
month_11.head()
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City  Revenue  Month
# 1      Gift Card    Tom Jackson  London  1999.77     11
# 2      Gift Card    Pablo Perez  Madrid  2200.70     11
# 3      Gift Card     Joao Silva  Lisbon   998.00     11
# 4    Credit Card  Walter Muller  Berlin  7404.30     11
# 5    Credit Card  Walter Muller  Berlin  1999.95     11

# %%
month_11.Revenue.sum()
# Out:
# np.float64(332015.11999999994)

# %%
month_12 = df[df['Month'] == 12]
month_12.head()
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 111     10570 2022-12-01             Burgers  12.99       493       Online
# 112     10571 2022-12-01  Chicken Sandwiches   9.95       201       Online
# 113     10572 2022-12-01               Fries   3.49       573       Online
# 114     10573 2022-12-01           Beverages   2.95       678       Online
# 115     10574 2022-12-01       Sides & Other   4.99       200       Online
#
# 0   Payment Method      Manager    City  Revenue  Month
# 111    Credit Card  Tom Jackson  London  6404.07     12
# 112    Credit Card  Tom Jackson  London  1999.95     12
# 113    Credit Card   Remy Monet   Paris  1999.77     12
# 114    Credit Card   Remy Monet   Paris  2000.10     12
# 115    Credit Card   Remy Monet   Paris   998.00     12

# %%
month_12.Revenue.sum()
# Out:
# np.float64(437284.32)

# %%
increasing = (((month_12.Revenue.sum()) / (month_11.Revenue.sum())) - 1) * 100
print(increasing)
# Out:
# 31.706146394778667

# %% [markdown]
# ### What was the Average 'Quantity Sold' & 'Average Revenue' for each product?

# %%
df.head()
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City  Revenue  Month
# 1      Gift Card    Tom Jackson  London  1999.77     11
# 2      Gift Card    Pablo Perez  Madrid  2200.70     11
# 3      Gift Card     Joao Silva  Lisbon   998.00     11
# 4    Credit Card  Walter Muller  Berlin  7404.30     11
# 5    Credit Card  Walter Muller  Berlin  1999.95     11

# %%
df.groupby('Product')[['Quantity', 'Revenue']].aggregate({'Quantity': 'mean', 'Revenue': 'mean'})
# Out:
# 0                     Quantity      Revenue
# Product
# Beverages           699.760000  2064.292000
# Burgers             558.038462  7248.919615
# Chicken Sandwiches  214.096154  2204.085577
# Fries               627.901961  2463.266078
# Sides & Other       200.000000   998.000000
